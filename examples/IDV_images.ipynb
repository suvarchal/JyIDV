# %%
showIdv()
# Out:
# 3D [dev] 1.6.0-pre9-daily-experimental daily
#
# libEGL warning: failed to create a pipe screen for i965

# %%
loadBundle("/home/suvarchal/IDV_5.2/monsoonloopbest.xidv")
# Out:
# <bundle  file="/home/suvarchal/IDV_5.2/monsoonloopbest.xidv" ></bundle>

# %%
showImg()

# %%
showImg(width=600,height=400)

# %%
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: showAxesScales(): expected 2 args; got 0
