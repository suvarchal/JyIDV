# %%
ds=makeDataSource("/home/suvarchal/gfs_eval/reforecast/temp/TRMM_3B42.2008_jja.daily.1deg.nc")

# %%
setOffScreen(True)
ds.dataChoices

# %%
dc=createDisplay('planviewcolor',getData(ds.getName(),ds.dataChoices[0]))

# %%
dc.setColorTableName("Blues")
dc.getRange().setMin(2.0)
dc.getRange().setMax(3.0)
dc.setColorScaleVisible(1)

# %%
#showImg('')

# %%
#showImg('clip north=40 south=-40 west=-180 east=180;displaylist valign=top mattebg=white fontsize=18 fontface=Arial color=black;matte bottom=30 background=white;colorbar orientation=bottom tickmarks=3 width=500 height=10 showlines=true  anchor=UM place=LM,0,-30 showunit=false')

# %%
Title = str("Precipitation TRMM")
dc.setDisplayListTemplate(Title)

# %% [markdown]
# # HEllo
# ## hello
# ### hello

# %%
#showImg('clip north=40 south=-40 west=-180 east=180;displaylist valign=top mattebg=white fontsize=18 fontface=Arial color=black;matte bottom=30 background=white;colorbar orientation=bottom tickmarks=3 width=500 height=10 showlines=true  anchor=UM place=LM,0,-30 showunit=false')

# %%
import java.awt.Color
idv.getViewManager().getNavigatedDisplay().getDisplayables()[2].getDisplayable(0).setColor(java.awt.Color(110,110,110))

# %%
#showImg('clip north=40 south=-40 west=-180 east=180;displaylist valign=top mattebg=white fontsize=18 fontface=Arial color=black;matte bottom=30 background=white;colorbar orientation=bottom tickmarks=3 width=500 height=10 showlines=true  anchor=UM place=LM,0,-30 showunit=false')

# %%
setOffScreen(True)
loadBundle("/home/suvarchal/gfs_eval/2008/accu_bundle2.xidv")
# Out:
# <bundle  file="/home/suvarchal/gfs_eval/2008/accu_bundle2.xidv" ></bundle>
# 3D [dev] 1.6.0-pre9-daily-experimental daily
#
# libEGL warning: failed to create a pipe screen for i965

# %%
#showImg('')

# %%
ds=idv.getDataSources()[0]

# %%
ds.dataChoices
# Out:
# [Total Precipitation, accumulated anamoly]

# %%
precip=getData(ds.getName(),ds.dataChoices[0])

# %%
dumpType(precip)
# Out:
# VisAD MathType analysis
#   FunctionType:
#   Domain has 1 components:
#    0. RealType: Time
#    0.   Name = Time
#    0.   Unit: s since 1970-01-01 00:00:00.000 UTC
#   Range:
#     FunctionType:
#     Domain has 2 components:
#      0. RealType: Longitude
#      0.   Name = Longitude
#      0.   Unit: deg
#      1. RealType: Latitude
#      1.   Name = Latitude
#      1.   Unit: deg
#     Range:
#       RealType: APCP_surface[unit:kg/m^2]
#         Name = APCP_surface[unit:kg/m^2]
#         Unit: kg/m^2

# %%
setOffScreen(False)
idv.getIdvUIManager().
precip=precip.POW(2)
dc=createDisplay('planviewcolor',precip)

# %%
#showImg('')

# %%
def ab
